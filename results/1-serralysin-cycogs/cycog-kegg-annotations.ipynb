# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
import requests
import json
import xarray as xr
import scipy.stats as stats
from scipy.stats import mannwhitneyu
from statsmodels.stats import multitest

# %% [markdown]
# # Assemble data inputs
#
# ## Reference genomes
#
# All reference genomes in this project were derived from the Scientific Data publication [Single cell genomes of Prochlorococcus, Synechococcus, and sympatric microbes from diverse marine environments](https://www.nature.com/articles/sdata2018154) (Berube et al., 2018). The genome sequences and annotations used in this publication are hosted by JGI on the [IMG/ProPortal](https://img.jgi.doe.gov/cgi-bin/proportal/main.cgi) and can be downloaded using the [IMG Genome Cart tool](https://img.jgi.doe.gov/cgi-bin/mer/main.cgi?section=GenomeCart&page=genomeCart). However, there is currently a mis-match in some of the genome ids used on JGI, and those used to generate CyCOGs v6.
# - Working solution: use the genomes given to us by the Chisholm/Berube group. Later these will be uploaded to a public repository.
# - Download genomes into the `../../data/genomes` directory.
#
# ## CyCOGs & genome metadata
#
# Download the following files from the [figshare site associated with Berube et al. (2018)](https://doi.org/10.6084/m9.figshare.c.4037048.v1) to the `../../data/cycogs/` directory:
# - File 4: [cycogs-genomes.tsv](https://figshare.com/articles/dataset/File_4_CyCOG_taxa/6007166)
# - File 5: [cycogs.tsv](https://figshare.com/articles/dataset/File_5_CyCOG_definitions/6007169)
# - File 14: [genome_assembly_summary_20180718.tsv](https://figshare.com/articles/dataset/File_14_Genome_assembly_summary/6281519)
#
# For convenience, also add the derived metadata files `ortholog-metadata.csv` and `genome-metadata.csv` to the `../../data/cycogs/` directory.
# - These files were generated by Stephen from various combined sources
# - In the future they will be replaced with the original source files

# %%
# genome metadata

# filepaths
filepath_genome_metadata = '../../data/cycogs/genome-metadata.csv'
filepath_ortholog_metadata = '../../data/cycogs/ortholog-metadata.csv'

# ortholog metadata
ortho_df = pd.read_csv(filepath_ortholog_metadata)

# genome metadata
assembly_sum_df = pd.read_csv('../../data/cycogs/cycogsgenomes.tsv', sep='\t')
genome_df = pd.merge(
    left=assembly_sum_df[['IID', 'GROUP', 'IMG_ID', 'Completeness']], 
    right=pd.read_csv(filepath_genome_metadata).drop(columns='Completeness'), 
    left_on='IMG_ID', 
    right_on='BerubeProportalID',
    how='left'
)

# fix typos
genome_df.loc[genome_df['Clade'] == '5.1A-1', 'Clade'] = '5.1A-I'
genome_df.loc[genome_df['Clade'] == 'CDR2', 'Clade'] = 'CRD2'
genome_df.loc[genome_df['GROUP'] == 'Uncultured-marine-virus', 'GROUP'] = 'Virus'

genome_df
# Out:
#              IID            GROUP      IMG_ID  Completeness  \
# 0     AG-311-D23  Prochlorococcus  2716884681         72.96
# 1     AG-311-I02  Prochlorococcus  2716884682         11.16
# 2     AG-311-I09  Prochlorococcus  2716884683         47.41
# 3     AG-311-J05  Prochlorococcus  2716884684         34.64
# 4     AG-311-J23  Prochlorococcus  2716884685         77.90
# ..           ...              ...         ...           ...
# 765       S-ShM2            Virus   651703106          0.00
# 766        Syn19            Virus   651703107          0.00
# 767         Syn5            Virus   641201056          0.00
# 768  metaG-MbCM1            Virus  2595698410          0.00
# 769         Syn9            Virus   638275565          0.00
#
#      BerubeProportalID  UpdatedProportalID  GenomeName            Genus  \
# 0         2.716885e+09        2.716885e+09  AG-311-D23  Prochlorococcus
# 1         2.716885e+09        2.716885e+09  AG-311-I02  Prochlorococcus
# 2         2.716885e+09        2.716885e+09  AG-311-I09  Prochlorococcus
# 3         2.716885e+09        2.716885e+09  AG-311-J05  Prochlorococcus
# 4         2.716885e+09        2.716885e+09  AG-311-J23  Prochlorococcus
# ..                 ...                 ...         ...              ...
# 765                NaN                 NaN         NaN              NaN
# 766                NaN                 NaN         NaN              NaN
# 767                NaN                 NaN         NaN              NaN
# 768                NaN                 NaN         NaN              NaN
# 769                NaN                 NaN         NaN              NaN
#
#                      Ecotype Clade ReferenceType    IsolationLocation  \
# 0     Low light adapted (LL)   LLI           SAG  South Pacific Ocean
# 1     Low light adapted (LL)   LLI           SAG  South Pacific Ocean
# 2    High light adapted (HL)   HLI           SAG  South Pacific Ocean
# 3    High light adapted (HL)   HLI           SAG  South Pacific Ocean
# 4     Low light adapted (LL)   LLI           SAG  South Pacific Ocean
# ..                       ...   ...           ...                  ...
# 765                      NaN   NaN           NaN                  NaN
# 766                      NaN   NaN           NaN                  NaN
# 767                      NaN   NaN           NaN                  NaN
# 768                      NaN   NaN           NaN                  NaN
# 769                      NaN   NaN           NaN                  NaN
#
#     Ecosystem  Latitude  Longitude  Depth(m)  GenomeSize(bp)  GeneCount
# 0     Pelagic    -20.08      -70.8      20.0       1466304.0     1796.0
# 1     Pelagic    -20.08      -70.8      20.0        195290.0      271.0
# 2     Pelagic    -20.08      -70.8      20.0        697970.0      812.0
# 3     Pelagic    -20.08      -70.8      20.0        623148.0      755.0
# 4     Pelagic    -20.08      -70.8      20.0       1427538.0     1677.0
# ..        ...       ...        ...       ...             ...        ...
# 765       NaN       NaN        NaN       NaN             NaN        NaN
# 766       NaN       NaN        NaN       NaN             NaN        NaN
# 767       NaN       NaN        NaN       NaN             NaN        NaN
# 768       NaN       NaN        NaN       NaN             NaN        NaN
# 769       NaN       NaN        NaN       NaN             NaN        NaN
#
# [770 rows x 18 columns]

# %%
# add genome id and clade info into ortholog df

ortho_df['GenomeID'] = ortho_df['GenomeName'].map(genome_df.set_index('IID')['IMG_ID'])
ortho_df['Group'] = ortho_df['GenomeName'].map(genome_df.set_index('IID')['GROUP'])
ortho_df['Clade'] = ortho_df['GenomeName'].map(genome_df.set_index('IID')['Clade'])

# fill N/A clades with 'Not Assigned'
ortho_df['Clade'] = ortho_df['Clade'].fillna('Not Assigned')

ortho_df
# Out:
#                       MappingName  OrthologID      GenomeName      GeneID  \
# 0               WH8102_2607658325    60000001          WH8102  2607658325
# 1              MIT0917_2681971350    60000001         MIT0917  2681971350
# 2           AG-424-P18_2717338506    60000001      AG-424-P18  2717338506
# 3       scB245a_521A19_2655604637    60000001  scB245a_521A19  2655604637
# 4                GFB01_2638208352    60000001           GFB01  2638208352
# ...                           ...         ...             ...         ...
# 964917      AG-363-C02_2667889608    60040295      AG-363-C02  2667889608
# 964918      AG-363-C02_2667889615    60040295      AG-363-C02  2667889615
# 964919      AG-363-C02_2667890048    60040295      AG-363-C02  2667890048
# 964920      AG-363-C02_2667890054    60040295      AG-363-C02  2667890054
# 964921      AG-363-C02_2667890060    60040295      AG-363-C02  2667890060
#
#                                       Annotation    GenomeID            Group  \
# 0       membrane protease FtsH catalytic subunit  2606217514    Synechococcus
# 1       membrane protease FtsH catalytic subunit  2681812859  Prochlorococcus
# 2       membrane protease FtsH catalytic subunit  2716884419  Prochlorococcus
# 3       membrane protease FtsH catalytic subunit  2654587735  Prochlorococcus
# 4       membrane protease FtsH catalytic subunit  2636415834    Synechococcus
# ...                                          ...         ...              ...
# 964917                      hypothetical protein  2667527365  Prochlorococcus
# 964918                      hypothetical protein  2667527365  Prochlorococcus
# 964919                      hypothetical protein  2667527365  Prochlorococcus
# 964920                      hypothetical protein  2667527365  Prochlorococcus
# 964921                      hypothetical protein  2667527365  Prochlorococcus
#
#                Clade
# 0           5.1A-III
# 1                LLI
# 2               HLII
# 3       Not Assigned
# 4       Not Assigned
# ...              ...
# 964917      LLII/III
# 964918      LLII/III
# 964919      LLII/III
# 964920      LLII/III
# 964921      LLII/III
#
# [964922 rows x 8 columns]

# %%
# start building ko mapping file

ko_map_df = ortho_df.groupby('OrthologID').GeneID.count().reset_index().rename(columns={'GeneID': 'TotalRefs'})
# add in genus and clade counts
for var in ['Group', 'Clade']:
    ko_map_df = ko_map_df.join(
        pd.DataFrame(ortho_df.groupby('OrthologID')[var].value_counts()).rename(
            columns={var: 'count'}).reset_index().pivot(
            columns=var, index='OrthologID', values='count').fillna(0), 
        on='OrthologID', 
        how='left'
    )
# convert dataframe back to ints
ko_map_df = ko_map_df.astype(int)
# add back CyCOG annotation
ko_map_df['DescriptionCyCOG'] = ko_map_df['OrthologID'].map(
    ortho_df[['OrthologID', 'Annotation']].drop_duplicates().set_index('OrthologID')['Annotation']
)

ko_map_df
# Out:
#        OrthologID  TotalRefs  Prochlorococcus  Synechococcus  Virus  5.1-UC-A  \
# 0        60000001       1376             1218            158      0         3
# 1        60000002       1453             1296            157      0         3
# 2        60000003       1387             1231            156      0         3
# 3        60000004       1631             1376            255      0         7
# 4        60000005        990              882            108      0         2
# ...           ...        ...              ...            ...    ...       ...
# 40290    60040291          4                4              0      0         0
# 40291    60040292          4                4              0      0         0
# 40292    60040293          5                0              5      0         0
# 40293    60040294          6                0              6      0         0
# 40294    60040295          6                6              0      0         0
#
#        5.1A-I  5.1A-II  5.1A-III  5.1A-III/XV  ...  CRD2  HLI  HLII  HLIII  \
# 0          13       17         5            3  ...    17  195   440      1
# 1          12       18         6            3  ...    10  196   464      0
# 2           8       16         6            2  ...    12  203   446      1
# 3          20       23        11           12  ...    22  170   477      0
# 4           9       11         3            3  ...     8  126   323      0
# ...       ...      ...       ...          ...  ...   ...  ...   ...    ...
# 40290       0        0         0            0  ...     0    0     0      0
# 40291       0        0         0            0  ...     0    0     0      0
# 40292       0        0         0            0  ...     0    0     0      0
# 40293       0        0         0            0  ...     0    0     0      0
# 40294       0        0         0            0  ...     0    0     0      0
#
#        HLVI  LLI  LLII/III  LLIV  Not Assigned  \
# 0        20  172        79    66           266
# 1        25  184        85    66           299
# 2        21  180        79    65           259
# 3        31  252        97   127           259
# 4        19  123        62    46           200
# ...     ...  ...       ...   ...           ...
# 40290     0    4         0     0             0
# 40291     0    4         0     0             0
# 40292     0    0         0     0             5
# 40293     0    0         0     0             6
# 40294     0    0         6     0             0
#
#                                         DescriptionCyCOG
# 0               membrane protease FtsH catalytic subunit
# 1      ATP-dependent Clp protease ATP-binding subunit...
# 2      ATP-dependent Clp protease proteolytic subunit...
# 3                                   hypothetical protein
# 4                                       chaperonin GroEL
# ...                                                  ...
# 40290                               hypothetical protein
# 40291  Tryptophan-rich Synechocystis species C-termin...
# 40292                               Putative transposase
# 40293  sulfate transport system substrate-binding pro...
# 40294                               hypothetical protein
#
# [40295 rows x 30 columns]

# %%
# check that there is a directory for each genome

data_path = Path('../../data/genomes')

count = 0
for g_id in ortho_df['GenomeID'].unique():
    if not os.path.isdir(data_path / str(g_id)):
        print(f'{g_id} directory not found: {data_path / str(g_id)}')
        count += 1
        
print(f'{count} total missing directories')
# Out:
# 0 total missing directories

# %%
# import all kegg annotations as a df

ko_df = pd.DataFrame()
for g_id in ortho_df['GenomeID'].unique():
    df = pd.read_csv(data_path / f'{g_id}/{g_id}.ko.tab.txt', sep='\t')
    if len(ko_df) == 0:
        ko_df = df
    else:
        ko_df = pd.concat([ko_df, df])
        
ko_df = ko_df.reset_index(drop=True)

ko_df
# Out:
#           gene_oid  gene_length  percent_identity  query_start  query_end  \
# 0       2607658051          465              99.8            1        465
# 1       2607658053          410             100.0            1        410
# 2       2607658055          455             100.0            1        455
# 3       2607658058          198             100.0            1        198
# 4       2607658059          562             100.0            1        562
# ...            ...          ...               ...          ...        ...
# 492987  2610145142          243              35.7           19        239
# 492988  2610145144          309              37.5            4        292
# 492989  2610145149          109              41.2            1         95
# 492990  2610145152          261              40.5            5        254
# 492991  2610145160          139              35.6            6        135
#
#         subj_start  subj_end        evalue  bit_score      ko_id  \
# 0                1       465  0.000000e+00      906.4  KO:K02313
# 1               11       420  0.000000e+00      856.7  KO:K00799
# 2                1       455  0.000000e+00      895.6  KO:K00383
# 3                1       198  0.000000e+00      409.1  KO:K02276
# 4                1       562  0.000000e+00     1173.7  KO:K02274
# ...            ...       ...           ...        ...        ...
# 492987          48       257  4.300000e-27      123.6  KO:K03791
# 492988          17       311  0.000000e+00      198.4  KO:K03086
# 492989           1        97  1.500000e-13       77.4  KO:K03111
# 492990          10       269  2.000000e-43      177.9  KO:K10906
# 492991           7       123  5.100000e-09       62.8  KO:K01160
#
#                                                   ko_name           EC  \
# 0               chromosomal replication initiator protein          NaN
# 1                 glutathione S-transferase [EC:2.5.1.18]  EC:2.5.1.18
# 2              glutathione reductase (NADPH) [EC:1.8.1.7]   EC:1.8.1.7
# 3           cytochrome c oxidase subunit III [EC:1.9.3.1]   EC:1.9.3.1
# 4             cytochrome c oxidase subunit I [EC:1.9.3.1]   EC:1.9.3.1
# ...                                                   ...          ...
# 492987                                 putative chitinase          NaN
# 492988                RNA polymerase primary sigma factor          NaN
# 492989                  single-strand DNA-binding protein          NaN
# 492990            exodeoxyribonuclease VIII [EC:3.1.11.-]  EC:3.1.11.-
# 492991  crossover junction endodeoxyribonuclease RusA ...  EC:3.1.22.4
#
#        img_ko_flag
# 0              Yes
# 1              Yes
# 2              Yes
# 3              Yes
# 4              Yes
# ...            ...
# 492987         Yes
# 492988         Yes
# 492989         Yes
# 492990         Yes
# 492991         Yes
#
# [492992 rows x 13 columns]

# %% [markdown]
# # Deduplicate gene annotations
#
# **Problem:** Some genes (specific nucleotide sequence from particular reference genome) have more than one KO annotation listed.
# - Based on the counts below, this comes out to 16,400 (15038 + 1352 + 9 + 1) out of 301,499 annotated genes, or ~5.44%.
# - Most of these are annotations that actually have the same KO number, but just a different EC number or something. Only 2,207 genes (0.73%) have multiple distinct KO annotations
# - Of these, qualitatively it seems like the annotations are usually quite similar to one another (e.g. same pathway, or different subunits of the same protein complex)
#
# **Proposed solution:** Since the KO annotations are based on an HMM search, first select the annotation with the lowest E-value. Then if the E-values are exactly the same, randomly select one annotaiton or the other

# %%
# how many genes have more than one ko number assigned?

print(ko_df['gene_oid'].value_counts().value_counts())
# Out:
# 1    440542
# 2     23227
# 3      1973
# 4        15
# 6         2
# 5         1
# Name: gene_oid, dtype: int64

# %%
# deeper look: examine genes with more than one annotation

counts = ko_df['gene_oid'].value_counts()
ko_counts = ko_df[ko_df['gene_oid'].isin(counts[counts.gt(1)].index)].groupby('gene_oid')['ko_id'].nunique()
print(ko_counts.value_counts())    # most have the same ko id, just different EC numbers or something

ko_df[ko_df['gene_oid'].isin(ko_counts[ko_counts.gt(1)].index)]
# Out:
# 1    21836
# 2     3333
# 3       48
# 4        1
# Name: ko_id, dtype: int64
#           gene_oid  gene_length  percent_identity  query_start  query_end  \
# 1549    2681971726          240             93.75            1        240
# 1550    2681971726          240             93.75            1        240
# 1561    2681971798          467             89.08            1        467
# 1562    2681971798          467             90.15            1        467
# 1620    2681971886          348             80.77            1        338
# ...            ...          ...               ...          ...        ...
# 492225  2717343036          149             41.86           15        140
# 492226  2717343036          149             44.78           15        145
# 492227  2717343036          149             44.78           15        145
# 492269  2717343185          112            100.00            1        112
# 492270  2717343185          112            100.00            1        112
#
#         subj_start  subj_end        evalue  bit_score      ko_id  \
# 1549             1       240  0.000000e+00      513.0  KO:K06182
# 1550             1       240  0.000000e+00      513.0  KO:K06183
# 1561             1       467  0.000000e+00      960.0  KO:K04094
# 1562             1       467  0.000000e+00      969.0  KO:K03495
# 1620             1       338  0.000000e+00      680.0  KO:K08919
# ...            ...       ...           ...        ...        ...
# 492225           4       132  6.500000e-31      126.0  KO:K00980
# 492226           4       137  3.000000e-36      141.0  KO:K03272
# 492227           4       137  3.000000e-36      141.0  KO:K03272
# 492269           1       112  1.400000e-73      243.0  KO:K04751
# 492270           1       112  1.400000e-73      243.0  KO:K04752
#
#                                                   ko_name            EC  \
# 1549    23S rRNA pseudouridine2604 synthase [EC:5.4.99...  EC:5.4.99.21
# 1550    16S rRNA pseudouridine516 synthase [EC:5.4.99.19]  EC:5.4.99.19
# 1561    methylenetetrahydrofolate--tRNA-(uracil-5-)-me...   EC:2.1.1.74
# 1562    tRNA uridine 5-carboxymethylaminomethyl modifi...           NaN
# 1620    chlorophyll a/b binding light-harvesting prote...           NaN
# ...                                                   ...           ...
# 492225  glycerol-3-phosphate cytidylyltransferase [EC:...   EC:2.7.7.39
# 492226  D-beta-D-heptose 7-phosphate kinase / D-beta-D...  EC:2.7.1.167
# 492227  D-beta-D-heptose 7-phosphate kinase / D-beta-D...   EC:2.7.7.70
# 492269                 nitrogen regulatory protein P-II 1           NaN
# 492270                 nitrogen regulatory protein P-II 2           NaN
#
#        img_ko_flag
# 1549           Yes
# 1550           Yes
# 1561           Yes
# 1562           Yes
# 1620           Yes
# ...            ...
# 492225         Yes
# 492226         Yes
# 492227         Yes
# 492269         Yes
# 492270         Yes
#
# [6881 rows x 13 columns]

# %%
# deduplicate genes with more than one annotation

# for each gene_oid's set of annotations, select the one with the lowest e-value
# this step will also randomly select one of the annotations to propogate in cases with the same KO 
# but different EC numbers, or different KOs but same e-value

ko_df = ko_df.loc[ko_df.groupby('gene_oid')['evalue'].idxmin(), :].reset_index(drop=True)
ko_df
# Out:
#           gene_oid  gene_length  percent_identity  query_start  query_end  \
# 0        638291477          531             48.40            4        522
# 1        638291481          243             43.10            5        240
# 2        638291512          235             61.80           26        231
# 3        638310966          295             49.20            2        294
# 4        638311025          200             32.50           49        200
# ...            ...          ...               ...          ...        ...
# 465755  2721491637          397             65.72           27        379
# 465756  2721491638          266             63.67           10        264
# 465757  2721491639          219             87.26            2        213
# 465758  2721491640          599             81.64            1        599
# 465759  2721491643          199             53.17            1        195
#
#         subj_start  subj_end         evalue  bit_score      ko_id  \
# 0                3       549   0.000000e+00      461.5  KO:K17680
# 1                3       242   1.500000e-37      158.3  KO:K02335
# 2                1       207   0.000000e+00      253.1  KO:K03465
# 3               32       309   0.000000e+00      283.1  KO:K06223
# 4               48       186   1.100000e-12       75.5  KO:K07336
# ...            ...       ...            ...        ...        ...
# 465755          39       383   0.000000e+00      514.0  KO:K02010
# 465756           5       250  3.500000e-107      354.0  KO:K01069
# 465757           1       212  9.000000e-129      411.0  KO:K00765
# 465758           1       599   0.000000e+00     1060.0  KO:K06147
# 465759          17       221   1.300000e-59      212.0  KO:K09931
#
#                                                   ko_name            EC  \
# 0                           twinkle protein [EC:3.6.4.12]   EC:3.6.4.12
# 1                           DNA polymerase I [EC:2.7.7.7]    EC:2.7.7.7
# 2               thymidylate synthase (FAD) [EC:2.1.1.148]  EC:2.1.1.148
# 3                     DNA adenine methylase [EC:2.1.1.72]   EC:2.1.1.72
# 4                    PKHD-type hydroxylase [EC:1.14.11.-]  EC:1.14.11.-
# ...                                                   ...           ...
# 465755  iron(III) transport system ATP-binding protein...   EC:3.6.3.30
# 465756      hydroxyacylglutathione hydrolase [EC:3.1.2.6]    EC:3.1.2.6
# 465757        ATP phosphoribosyltransferase [EC:2.4.2.17]   EC:2.4.2.17
# 465758       ATP-binding cassette, subfamily B, bacterial           NaN
# 465759                            uncharacterized protein           NaN
#
#        img_ko_flag
# 0              Yes
# 1              Yes
# 2              Yes
# 3              Yes
# 4              Yes
# ...            ...
# 465755         Yes
# 465756         Yes
# 465757         Yes
# 465758         Yes
# 465759         Yes
#
# [465760 rows x 13 columns]

# %% [markdown]
# # Deduplicate CyCOG annotations
#
# **Problem:** Some CyCOG (Clusters of Orthologous Genes) consist of genes with discordant KO annotations
# - Out of 20,502 CyCOGs represented by the clades we're considering in this study, 18,132 had no KO annotation, meaning just 2,370 (11.56%) contained at least one gene with a KO annotation.
# - In most of the annotated CyCOGs, all gene members had a concordant KO annotation. In 93 (3.94% of annotated CyCOGs), the KO annotations were discordant among gene members.
# - Of these, qualitatively it seems like the discordant annotations are usually quite similar to one another (e.g. same pathway, or different subunits of the same protein complex)
#
# **Proposed solution:** For each CyCOG, select the annotation applied to the majority of members as the representatitve CyCOG annotation.

# %%
# join kegg annotations onto reference gene set

annot_df = pd.merge(ortho_df, ko_df, left_on='GeneID', right_on='gene_oid', how='left')

# how many unique ko annotations per ortholog group?
print(annot_df.groupby('OrthologID').ko_id.nunique().value_counts())

# drop the sequences without a ko annotation
annot_df = annot_df[annot_df['ko_id'].notna()]

annot_df
# Out:
# 0     36693
# 1      3474
# 2        94
# 3        14
# 4        13
# 7         2
# 9         2
# 5         1
# 8         1
# 10        1
# Name: ko_id, dtype: int64
#                       MappingName  OrthologID      GenomeName      GeneID  \
# 0               WH8102_2607658325    60000001          WH8102  2607658325
# 1              MIT0917_2681971350    60000001         MIT0917  2681971350
# 2           AG-424-P18_2717338506    60000001      AG-424-P18  2717338506
# 3       scB245a_521A19_2655604637    60000001  scB245a_521A19  2655604637
# 4                GFB01_2638208352    60000001           GFB01  2638208352
# ...                           ...         ...             ...         ...
# 964878        KORDI-49_2507312281    60040286        KORDI-49  2507312281
# 964910           GFB01_2638207649    60040294           GFB01  2638207649
# 964911           GFB01_2638207687    60040294           GFB01  2638207687
# 964912           GFB01_2638207688    60040294           GFB01  2638207688
# 964913           GFB01_2638207651    60040294           GFB01  2638207651
#
#                                                Annotation    GenomeID  \
# 0                membrane protease FtsH catalytic subunit  2606217514
# 1                membrane protease FtsH catalytic subunit  2681812859
# 2                membrane protease FtsH catalytic subunit  2716884419
# 3                membrane protease FtsH catalytic subunit  2654587735
# 4                membrane protease FtsH catalytic subunit  2636415834
# ...                                                   ...         ...
# 964878                               hypothetical protein  2507262011
# 964910  sulfate transport system substrate-binding pro...  2636415834
# 964911  sulfate transport system substrate-binding pro...  2636415834
# 964912  sulfate transport system substrate-binding pro...  2636415834
# 964913  sulfate transport system substrate-binding pro...  2636415834
#
#                   Group         Clade      gene_oid  gene_length  ...  \
# 0         Synechococcus      5.1A-III  2.607658e+09        637.0  ...
# 1       Prochlorococcus           LLI  2.681971e+09        640.0  ...
# 2       Prochlorococcus          HLII  2.717339e+09        584.0  ...
# 3       Prochlorococcus  Not Assigned  2.655605e+09        584.0  ...
# 4         Synechococcus  Not Assigned  2.638208e+09        646.0  ...
# ...                 ...           ...           ...          ...  ...
# 964878    Synechococcus     5.1A-WPC1  2.507312e+09       1889.0  ...
# 964910    Synechococcus  Not Assigned  2.638208e+09        289.0  ...
# 964911    Synechococcus  Not Assigned  2.638208e+09        338.0  ...
# 964912    Synechococcus  Not Assigned  2.638208e+09        348.0  ...
# 964913    Synechococcus  Not Assigned  2.638208e+09        306.0  ...
#
#         query_start  query_end  subj_start  subj_end  evalue  bit_score  \
# 0               1.0      637.0         1.0     637.0     0.0     1240.7
# 1               1.0      640.0         1.0     640.0     0.0     1370.0
# 2               1.0      584.0         1.0     584.0     0.0     1260.0
# 3               1.0      584.0         1.0     584.0     0.0     1250.0
# 4               1.0      643.0         1.0     643.0     0.0     1134.4
# ...             ...        ...         ...       ...     ...        ...
# 964878          1.0     1889.0         1.0    1889.0     0.0     3815.0
# 964910          7.0      280.0         6.0     279.0     0.0      389.4
# 964911          7.0      338.0         6.0     338.0     0.0      449.5
# 964912         10.0      348.0        19.0     363.0     0.0      502.3
# 964913         10.0      269.0        19.0     284.0     0.0      384.8
#
#             ko_id                                            ko_name  \
# 0       KO:K03798          cell division protease FtsH [EC:3.4.24.-]
# 1       KO:K03798          cell division protease FtsH [EC:3.4.24.-]
# 2       KO:K03798          cell division protease FtsH [EC:3.4.24.-]
# 3       KO:K03798          cell division protease FtsH [EC:3.4.24.-]
# 4       KO:K03798          cell division protease FtsH [EC:3.4.24.-]
# ...           ...                                                ...
# 964878  KO:K07004                                                NaN
# 964910  KO:K02048  sulfate transport system substrate-binding pro...
# 964911  KO:K02048  sulfate transport system substrate-binding pro...
# 964912  KO:K02048  sulfate transport system substrate-binding pro...
# 964913  KO:K02048  sulfate transport system substrate-binding pro...
#
#                  EC img_ko_flag
# 0       EC:3.4.24.-         Yes
# 1       EC:3.4.24.-         Yes
# 2       EC:3.4.24.-         Yes
# 3       EC:3.4.24.-         Yes
# 4       EC:3.4.24.-         Yes
# ...             ...         ...
# 964878          NaN         Yes
# 964910          NaN         Yes
# 964911          NaN         Yes
# 964912          NaN         Yes
# 964913          NaN         Yes
#
# [465760 rows x 21 columns]

# %%
# look at non-unique ko mappings

counts = annot_df.groupby('OrthologID').ko_id.nunique()
collisions_df = annot_df[annot_df['OrthologID'].isin(counts[counts.gt(1)].index)].groupby('OrthologID')[
    ['ko_id', 'ko_name']].value_counts().reset_index()

pd.set_option('max_colwidth', None)
collisions_df
# Out:
#      OrthologID      ko_id  \
# 0      60000002  KO:K03696
# 1      60000002  KO:K03695
# 2      60000006  KO:K11329
# 3      60000006  KO:K07659
# 4      60000006  KO:K07657
# ..          ...        ...
# 317    60014461  KO:K05879
# 318    60014461  KO:K05878
# 319    60014461  KO:K00863
# 320    60040231  KO:K11951
# 321    60040231  KO:K15577
#
#                                                                           ko_name  \
# 0                             ATP-dependent Clp protease ATP-binding subunit ClpC
# 1                             ATP-dependent Clp protease ATP-binding subunit ClpB
# 2                      two-component system, OmpR family, response regulator RpaB
# 3    two-component system, OmpR family, phosphate regulon response regulator OmpR
# 4    two-component system, OmpR family, phosphate regulon response regulator PhoB
# ..                                                                            ...
# 317                       dihydroxyacetone kinase, C-terminal domain [EC:2.7.1.-]
# 318                       dihydroxyacetone kinase, N-terminal domain [EC:2.7.1.-]
# 319                                         dihydroxyacetone kinase [EC:2.7.1.29]
# 320                                 bicarbonate transport system permease protein
# 321                             nitrate/nitrite transport system permease protein
#
#        0
# 0    443
# 1    417
# 2    452
# 3     73
# 4     34
# ..   ...
# 317    1
# 318    1
# 319    1
# 320    1
# 321    1
#
# [322 rows x 4 columns]

# %%
# deduplicate the discordant ortholog-ko mapping by simple majority vote

ko_count_df = pd.DataFrame(annot_df.groupby('OrthologID').ko_id.value_counts()).rename(
    columns={'ko_id': 'count'}).reset_index()
ko_count_df = ko_count_df.loc[ko_count_df.groupby('OrthologID')['count'].idxmax(), :]

# add in KO annotation
name_map = annot_df[['ko_id', 'ko_name']].drop_duplicates()
name_map['DescriptionKO'] = name_map['ko_name'].str.split(' \[EC:').str[0]
name_map = name_map.loc[name_map['ko_id'].drop_duplicates().index]    # pick one description from duplicates
ko_count_df = pd.merge(left=ko_count_df, right=name_map[['ko_id', 'DescriptionKO']], on='ko_id', how='left')

# remove prefix from KOID
ko_count_df['KOID'] = ko_count_df['ko_id'].str[3:]
# rename count column and drop old ko_id column
ko_count_df = ko_count_df[['OrthologID', 'KOID', 'DescriptionKO', 'count']].rename(
    columns={'count': 'NRefsKO'}).set_index('OrthologID')
# calculate refs with KO mapping other than the one chosen
ko_count_df['NRefsOtherKO'] = annot_df.groupby('OrthologID').GeneID.count() - ko_count_df['NRefsKO']

# add ko_count_df into ko_map_df
ko_map_df = pd.merge(ko_map_df, ko_count_df, on='OrthologID', how='left')

pd.reset_option('max_colwidth')
ko_map_df
# Out:
#        OrthologID  TotalRefs  Prochlorococcus  Synechococcus  Virus  5.1-UC-A  \
# 0        60000001       1376             1218            158      0         3
# 1        60000002       1453             1296            157      0         3
# 2        60000003       1387             1231            156      0         3
# 3        60000004       1631             1376            255      0         7
# 4        60000005        990              882            108      0         2
# ...           ...        ...              ...            ...    ...       ...
# 40290    60040291          4                4              0      0         0
# 40291    60040292          4                4              0      0         0
# 40292    60040293          5                0              5      0         0
# 40293    60040294          6                0              6      0         0
# 40294    60040295          6                6              0      0         0
#
#        5.1A-I  5.1A-II  5.1A-III  5.1A-III/XV  ...  HLVI  LLI  LLII/III  LLIV  \
# 0          13       17         5            3  ...    20  172        79    66
# 1          12       18         6            3  ...    25  184        85    66
# 2           8       16         6            2  ...    21  180        79    65
# 3          20       23        11           12  ...    31  252        97   127
# 4           9       11         3            3  ...    19  123        62    46
# ...       ...      ...       ...          ...  ...   ...  ...       ...   ...
# 40290       0        0         0            0  ...     0    4         0     0
# 40291       0        0         0            0  ...     0    4         0     0
# 40292       0        0         0            0  ...     0    0         0     0
# 40293       0        0         0            0  ...     0    0         0     0
# 40294       0        0         0            0  ...     0    0         6     0
#
#        Not Assigned                                   DescriptionCyCOG  \
# 0               266           membrane protease FtsH catalytic subunit
# 1               299  ATP-dependent Clp protease ATP-binding subunit...
# 2               259  ATP-dependent Clp protease proteolytic subunit...
# 3               259                               hypothetical protein
# 4               200                                   chaperonin GroEL
# ...             ...                                                ...
# 40290             0                               hypothetical protein
# 40291             0  Tryptophan-rich Synechocystis species C-termin...
# 40292             5                               Putative transposase
# 40293             6  sulfate transport system substrate-binding pro...
# 40294             0                               hypothetical protein
#
#          KOID                                      DescriptionKO  NRefsKO  \
# 0      K03798                        cell division protease FtsH   1291.0
# 1      K03696  ATP-dependent Clp protease ATP-binding subunit...    443.0
# 2      K01358       ATP-dependent Clp protease, protease subunit   1360.0
# 3         NaN                                                NaN      NaN
# 4      K04077                                   chaperonin GroEL    935.0
# ...       ...                                                ...      ...
# 40290     NaN                                                NaN      NaN
# 40291     NaN                                                NaN      NaN
# 40292     NaN                                                NaN      NaN
# 40293  K02048  sulfate transport system substrate-binding pro...      4.0
# 40294     NaN                                                NaN      NaN
#
#        NRefsOtherKO
# 0               0.0
# 1             417.0
# 2               0.0
# 3               NaN
# 4               0.0
# ...             ...
# 40290           NaN
# 40291           NaN
# 40292           NaN
# 40293           0.0
# 40294           NaN
#
# [40295 rows x 34 columns]

# %%
# there are many different CyCOG orthologies annotated with the same KO group -- look at some of these

ko_map_counts = ko_map_df['KOID'].value_counts()
print('There are {} of {} KOs with a non-unique CyCOGID-KOID mapping:'.format(
    len(ko_map_counts[ko_map_counts.gt(1)]), ko_map_df['KOID'].nunique()))
print(ko_map_counts[ko_map_counts.gt(1)].head(20))

# look at serralysin KOIDs
ko_map_df[ko_map_df['KOID'] == 'K01406'].head(10)

# NOTE: these are the CyCOGs in which the serralysin annotation is the majority KEGG annotation
# Out:
# There are 669 of 1748 KOs with a non-unique CyCOGID-KOID mapping:
# K06147    62
# K01784    41
# K01953    37
# K01154    28
# K03090    24
# K07257    23
# K01652    20
# K00067    18
# K01790    18
# K00615    18
# K00059    17
# K02500    17
# K00604    17
# K02501    16
# K00058    16
# K03086    16
# K00161    15
# K05577    15
# K00558    14
# K01710    14
# Name: KOID, dtype: int64
#        OrthologID  TotalRefs  Prochlorococcus  Synechococcus  Virus  5.1-UC-A  \
# 1829     60001830        488              322            166      0        14
# 1882     60001883        507              495             12      0         0
# 1887     60001888        351              313             33      5         2
# 2364     60002365        127               96             31      0         1
# 5973     60005974          7                0              7      0         0
# 7889     60007890          4                4              0      0         0
# 12357    60012358          2                2              0      0         0
# 16844    60016845          1                1              0      0         0
# 21516    60021517          1                1              0      0         0
# 21871    60021872          1                0              1      0         0
#
#        5.1A-I  5.1A-II  5.1A-III  5.1A-III/XV  ...  HLVI  LLI  LLII/III  LLIV  \
# 1829        4        7         8           26  ...     0   23         0   149
# 1882        0        0         2            0  ...     1  384         0     3
# 1887        0        1         2            7  ...     9   44        17   119
# 2364        1        5         0            1  ...     0   25         1     2
# 5973        0        2         0            0  ...     0    0         0     0
# 7889        0        0         0            0  ...     0    4         0     0
# 12357       0        0         0            0  ...     0    0         0     2
# 16844       0        0         0            0  ...     0    1         0     0
# 21516       0        0         0            0  ...     0    0         0     1
# 21871       1        0         0            0  ...     0    0         0     0
#
#        Not Assigned                              DescriptionCyCOG    KOID  \
# 1829            107                          hypothetical protein  K01406
# 1882             36         protein of unknown function (DUF4214)  K01406
# 1887             61                          hypothetical protein  K01406
# 2364             19                          hypothetical protein  K01406
# 5973              0                                    serralysin  K01406
# 7889              0                          hypothetical protein  K01406
# 12357             0                          hypothetical protein  K01406
# 16844             0                                    serralysin  K01406
# 21516             0  Matrixin/Peptidase M10 serralysin C terminal  K01406
# 21871             0           Peptidase M10 serralysin C terminal  K01406
#
#        DescriptionKO  NRefsKO  NRefsOtherKO
# 1829      serralysin      4.0           4.0
# 1882      serralysin     14.0          15.0
# 1887      serralysin     21.0          23.0
# 2364      serralysin      4.0           0.0
# 5973      serralysin      6.0           0.0
# 7889      serralysin      1.0           0.0
# 12357     serralysin      1.0           0.0
# 16844     serralysin      1.0           0.0
# 21516     serralysin      1.0           0.0
# 21871     serralysin      1.0           0.0
#
# [10 rows x 34 columns]

# %%
# for each "serralysin" CyCOG family, look at all of the KEGG annotations recruited

serralysin_cycogs = [60001830, 60001883, 60001888, 60002365]
serralysin_proteins_df = annot_df[annot_df['OrthologID'].isin(serralysin_cycogs)]
serralysin_proteins_df.groupby(['OrthologID'])[['ko_id', 'ko_name']].value_counts()

# review reference on type IV pili: https://www.nature.com/articles/s41579-019-0195-4
# Out:
# OrthologID  ko_id      ko_name
# 60001830    KO:K01406  serralysin [EC:3.4.24.40]                                   4
#             KO:K01113  alkaline phosphatase D [EC:3.1.3.1]                         2
#             KO:K01317  acrosin [EC:3.4.21.10]                                      1
#             KO:K03646  colicin import membrane protein                             1
# 60001883    KO:K01406  serralysin [EC:3.4.24.40]                                  14
#             KO:K09691  lipopolysaccharide transport system ATP-binding protein     9
#             KO:K03932  polyhydroxybutyrate depolymerase                            4
#             KO:K12544  S-layer protein                                             2
# 60001888    KO:K01406  serralysin [EC:3.4.24.40]                                  21
#             KO:K02650  type IV pilus assembly protein PilA                        20
#             KO:K10924  MSHA pilin protein MshA                                     2
#             KO:K02456  general secretion pathway protein G                         1
# 60002365    KO:K01406  serralysin [EC:3.4.24.40]                                   4
# dtype: int64

# %%
# look at all CyCOGs with any reference containing a "serralysin" annotation

annot_df[annot_df['ko_id'] == 'KO:K01406'].groupby('OrthologID').ko_id.value_counts()

# these are all the same CyCOGs as above, so no new CyCOG families with serralysin annotations
# Out:
# OrthologID  ko_id
# 60001830    KO:K01406     4
# 60001883    KO:K01406    14
# 60001888    KO:K01406    21
# 60002365    KO:K01406     4
# 60005974    KO:K01406     6
# 60007890    KO:K01406     1
# 60012358    KO:K01406     1
# 60016845    KO:K01406     1
# 60021517    KO:K01406     1
# 60021872    KO:K01406     1
# Name: ko_id, dtype: int64

# %% [markdown]
# # Get "serralysin" family strains

# %%
# get list of all strains with representatives in one of four "serralysin" CyCOG families

serralysin_cycogs = [60001830, 60001883, 60001888, 60002365]
serralysin_refs_df = ortho_df[ortho_df.OrthologID.isin(serralysin_cycogs)]
# add in isolate information
serralysin_refs_df['RefType'] = serralysin_refs_df['GenomeID'].map(
    assembly_sum_df.set_index('IMG_ID')['TYPE'])

# sort
serralysin_refs_df = serralysin_refs_df.sort_values(
    ['Group', 'Clade', 'RefType', 'GenomeName', 'OrthologID']
).reset_index(drop=True)

# save csv
serralysin_refs_df.to_csv('data/serralysin_cycog_references.csv', index=False)

# show how many copies per reference
pd.set_option('display.max_rows', 500)
serralysin_refs_df.groupby(['Group', 'Clade', 'RefType', 'GenomeName']).OrthologID.value_counts()
# Out:
# /var/folders/w0/7pz54fg92csc1bv996cgrss80000gn/T/ipykernel_40222/1532952077.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   serralysin_refs_df['RefType'] = serralysin_refs_df['GenomeID'].map(
# Group            Clade         RefType  GenomeName      OrthologID
# Prochlorococcus  HLI           SAG      AG-321-G20      60002365       1
#                                         AG-321-M21      60002365       4
#                                         AG-321-P21      60002365       2
#                                         AG-335-C21      60001883       1
#                                                         60001888       1
#                                         AG-335-E22      60002365       4
#                                         AG-388-B05      60001888       2
#                                         AG-402-N10      60001888       2
#                                         AG-469-F22      60001888       3
#                                                         60001830       2
#                                         AG-670-L08      60001888       5
#                                                         60001830       1
#                                         AG-676-L21      60001888       1
#                                         AG-676-M04      60001888       8
#                                         AG-676-P03      60001883       4
#                                         AG-676-P23      60001888       1
#                                         AG-686-P21      60002365       1
#                  HLII          ISOLATE  AS9601          60001883       1
#                                         GP2             60001830       1
#                                                         60001888       1
#                                         MIT9201         60001888       3
#                                                         60002365       1
#                                         MIT9302         60001888       1
#                                         SB              60001830       9
#                                                         60001888       1
#                                SAG      AG-347-C10      60001830       5
#                                         AG-347-G18      60001883       1
#                                         AG-347-I15      60001830       3
#                                                         60001888       1
#                                         AG-347-I22      60001830       5
#                                         AG-347-J21      60002365       2
#                                         AG-347-K16      60001883       2
#                                         AG-347-K20      60001883       2
#                                         AG-347-L13      60001830       1
#                                         AG-347-L19      60001883       1
#                                         AG-347-M23      60001888       1
#                                         AG-347-N23      60001888       1
#                                         AG-347-O22      60001830       1
#                                         AG-355-B18      60002365       3
#                                         AG-355-B23      60001883       1
#                                         AG-355-I20      60002365       4
#                                         AG-355-J09      60002365       5
#                                                         60001830       2
#                                         AG-355-J17      60001883       1
#                                         AG-355-J23      60001888       2
#                                         AG-355-L21      60001888       1
#                                                         60002365       1
#                                         AG-355-N02      60001830       1
#                                         AG-355-N16      60001883       1
#                                                         60002365       1
#                                         AG-355-N18      60001888       6
#                                                         60001883       3
#                                                         60002365       1
#                                         AG-355-O17      60001830       2
#                                         AG-355-P07      60001888       2
#                                         AG-355-P18      60001883       2
#                                         AG-388-F11      60001888       1
#                                         AG-402-A04      60001883       4
#                                                         60001830       1
#                                         AG-402-C22      60002365       2
#                                         AG-402-F05      60001883      12
#                                                         60001888       4
#                                                         60002365       4
#                                                         60001830       1
#                                         AG-402-G23      60001883       2
#                                                         60002365       2
#                                                         60001830       1
#                                         AG-402-K16      60001888       6
#                                                         60001883       3
#                                                         60002365       1
#                                         AG-402-K22      60001830       3
#                                                         60001883       2
#                                                         60001888       2
#                                                         60002365       1
#                                         AG-402-L23      60001883      10
#                                                         60002365       3
#                                                         60001830       1
#                                                         60001888       1
#                                         AG-412-A14      60001888       1
#                                         AG-412-J13      60001883      10
#                                                         60001830       3
#                                                         60001888       3
#                                                         60002365       1
#                                         AG-418-B17      60001883       2
#                                         AG-418-C17      60001883       1
#                                         AG-418-D13      60001883       2
#                                                         60001888       1
#                                         AG-418-F08      60001830       1
#                                                         60001888       1
#                                                         60002365       1
#                                         AG-418-F16      60001888       1
#                                         AG-418-J17      60001883       3
#                                         AG-418-J19      60002365       1
#                                         AG-418-K17      60001888       1
#                                         AG-418-P13      60001830       4
#                                                         60001888       1
#                                         AG-424-A14      60002365       2
#                                                         60001830       1
#                                                         60001888       1
#                                         AG-424-G03      60002365       3
#                                         AG-424-L22      60001888       2
#                                         AG-432-K16      60002365       2
#                                         AG-449-K21      60001830       1
#                                                         60001883       1
#                                         AG-449-O05      60001830       2
#                                         AG-455-E15      60001888       1
#                                         AG-459-A02      60001830       5
#                                                         60001888       1
#                                         AG-459-E08      60001888       1
#                                         AG-670-J21      60001888       1
#                                         AG-670-M15      60001830       4
#                                         AG-670-M18      60001888       1
#                                         AG-686-I20      60001830       1
#                  HLVI          SAG      AG-363-P06      60001883       1
#                                         AG-409-E23      60001888       3
#                                         AG-436-O11      60001888       6
#                  LLI           ISOLATE  MIT0801         60001883      11
#                                                         60001888       7
#                                         MIT0912         60001883       5
#                                                         60001830       1
#                                         MIT0913         60001883       4
#                                                         60001830       1
#                                         MIT0915         60001830       3
#                                                         60001883       2
#                                                         60001888       1
#                                                         60002365       1
#                                         MIT0917         60001883       5
#                                         MIT1013         60001888       6
#                                                         60001883       1
#                                         MIT1214         60001883       7
#                                         NATL1A          60001883       8
#                                                         60001830       1
#                                         NATL2A          60001883      15
#                                         PAC1            60001883       2
#                                                         60002365       2
#                                                         60001830       1
#                                                         60001888       1
#                                SAG      AG-311-D23      60001883       5
#                                         AG-311-I02      60001883       1
#                                         AG-311-J23      60001883       8
#                                         AG-311-K14      60001883       1
#                                         AG-311-K21      60001883       5
#                                         AG-311-L21      60001883       5
#                                         AG-311-N19      60001883       2
#                                         AG-315-C22      60001883       5
#                                                         60001888       1
#                                         AG-331-A01      60001883       5
#                                         AG-331-C07      60001883       8
#                                         AG-331-D10      60001883       6
#                                         AG-331-K04      60001883       2
#                                         AG-331-M18      60002365      12
#                                                         60001883       3
#                                                         60001830       1
#                                         AG-341-E15      60001883       2
#                                                         60002365       1
#                                         AG-341-K02      60001883       8
#                                         AG-341-K05      60001883       1
#                                                         60001888       1
#                                         AG-341-L22      60001883       1
#                                         AG-341-N05      60001883       2
#                                         AG-363-A03      60001883       1
#                                         AG-363-A04      60001883       5
#                                         AG-363-B05      60001888       2
#                                         AG-363-B19      60001883       1
#                                         AG-363-G03      60001883       2
#                                         AG-363-M20      60002365       2
#                                                         60001830       1
#                                                         60001888       1
#                                         AG-388-L21      60001883       6
#                                                         60001830       1
#                                         AG-388-O02      60001883       9
#                                         AG-402-A08      60001883       7
#                                         AG-402-A21      60001883       5
#                                         AG-402-B03      60001883       4
#                                         AG-402-B05      60001883       3
#                                                         60001830       2
#                                                         60002365       2
#                                                         60001888       1
#                                         AG-402-B10      60001883       3
#                                         AG-402-B19      60001888       2
#                                         AG-402-C09      60001883       4
#                                         AG-402-E17      60001888       1
#                                         AG-402-G06      60001883       5
#                                         AG-402-G08      60001883       4
#                                                         60001888       4
#                                                         60001830       2
#                                         AG-402-G19      60001883       3
#                                                         60001830       1
#                                         AG-402-I05      60001830       3
#                                                         60001883       3
#                                         AG-402-I20      60001883       9
#                                                         60001888       1
#                                         AG-402-I21      60001883       5
#                                                         60001888       2
#                                         AG-402-I22      60001883      12
#                                         AG-402-J18      60001888       3
#                                         AG-402-K04      60001883       3
#                                                         60002365       1
#                                         AG-402-K14      60001883      10
#                                                         60001830       1
#                                         AG-402-L09      60001883       1
#                                         AG-402-L19      60001888       7
#                                                         60001883       1
#                                         AG-402-L20      60001883       9
#                                         AG-402-M18      60001883       9
#                                                         60001830       1
#                                         AG-402-M23      60001883       3
#                                         AG-402-N09      60001883       7
#                                         AG-402-O21      60001883      11
#                                                         60002365       1
#                                         AG-402-P16      60001883       5
#                                         AG-402-P18      60001883       5
#                                         AG-409-A10      60001883      11
#                                         AG-409-D14      60001883       4
#                                         AG-409-J03      60001883      10
#                                                         60002365       1
#                                         AG-412-G19      60001883       4
#                                         AG-412-O03      60001883       7
#                                         AG-424-E20      60001883       6
#                                                         60001830       1
#                                         AG-429-J03      60001883       1
#                                         AG-432-A07      60001883       5
#                                                         60001888       1
#                                         AG-432-B15      60001883       1
#                                                         60001888       1
#                                         AG-432-E11      60001883       9
#                                         AG-432-K17      60001883       3
#                                                         60002365       1
#                                         AG-436-C14      60001883       4
#                                                         60001888       1
#                                         AG-455-B05      60001883       1
#                                         AG-455-G08      60001883       6
#                                                         60002365       1
#                                         AG-459-C18      60001883       6
#                                         AG-459-P07      60001883       6
#                                         AG-673-K22      60001883       7
#                                         AG-679-I23      60001883       8
#                                                         60001830       2
#                  LLII/III      ISOLATE  MIT0601         60001888       1
#                                         MIT0919         60001888       1
#                                         MIT1304         60001888       4
#                                         MIT9211         60001888       1
#                                SAG      AG-363-B11      60001888       1
#                                         AG-363-N16      60001888       3
#                                         AG-402-G22      60001888       1
#                                         AG-409-K04      60001888       1
#                                         AG-432-D11      60002365       1
#                                         AG-436-O09      60001888       4
#                  LLIV          ISOLATE  MIT0701         60001830       7
#                                                         60001888       5
#                                         MIT0702         60001830       7
#                                                         60001888       5
#                                         MIT0703         60001830       7
#                                                         60001888       5
#                                         MIT1205         60001888       6
#                                                         60001830       3
#                                         MIT1227         60001888       9
#                                                         60001830       3
#                                         MIT1303         60001830      12
#                                                         60001888       6
#                                         MIT1306         60001830       6
#                                                         60001888       6
#                                         MIT1312         60001888      11
#                                                         60001830       4
#                                         MIT1313         60001888       9
#                                                         60001830       7
#                                         MIT1318         60001888      11
#                                                         60001830       7
#                                         MIT1320         60001830      14
#                                         MIT1323         60001830       8
#                                                         60001888       6
#                                         MIT1327         60001888      14
#                                                         60001830       4
#                                         MIT1342         60001830      10
#                                                         60001883       1
#                                         MIT1418         60001830       7
#                                                         60001888       4
#                                         MIT9303         60001830      11
#                                         MIT9313         60001830       4
#                                SAG      AG-412-I05      60001830       4
#                                         AG-412-I20      60001888      12
#                                                         60001830       2
#                                                         60002365       1
#                                         AG-412-L10      60001830       5
#                                         AG-432-D09      60001830       3
#                                         AG-436-J08      60001888       8
#                                                         60001830       2
#                                                         60002365       1
#                                         AG-436-P23      60001830       8
#                                                         60001888       1
#                                         AG-463-F02      60001830       3
#                                                         60001888       1
#                                         AG-463-P23      60001883       2
#                                                         60001830       1
#                  Not Assigned  ISOLATE  MIT1300         60001830       6
#                                SAG      AG-315-A03      60001883       2
#                                         AG-315-B03      60001883       2
#                                         AG-315-C08      60001883       6
#                                                         60001888       1
#                                         AG-315-D17      60001888       9
#                                                         60001883       3
#                                                         60002365       1
#                                         AG-315-I10      60001883       3
#                                         AG-315-I14      60001888       5
#                                                         60001883       2
#                                         AG-315-K21      60001830       1
#                                         AG-315-L02      60001883       2
#                                         AG-315-L09      60001883       1
#                                         AG-315-M16      60001883       3
#                                         AG-315-N18      60001883       5
#                                                         60002365       1
#                                         AG-315-O03      60001883       3
#                                         AG-316-A05      60001888       2
#                                         AG-316-G21      60001830       2
#                                         AG-316-L16      60001888      11
#                                                         60001830       1
#                                         AG-316-L21      60001888       1
#                                         AG-316-N21      60001888       7
#                                                         60001830       1
#                                         AG-316-N23      60001830       3
#                                                         60001888       2
#                                         AG-363-A06      60001830       2
#                                         AG-363-B04      60001830       3
#                                         AG-363-I04      60001830       2
#                                         AG-363-J23      60001830       3
#                                         AG-363-L19      60001830       1
#                                                         60002365       1
#                                         AG-363-O06      60001830       1
#                                         AG-363-O15      60001830       4
#                                         AG-363-O16      60001830       2
#                                         AG-363-P01      60001888       3
#                                                         60002365       3
#                                                         60001830       2
#                                         AG-402-K05      60001830       2
#                                         AG-409-A19      60001830       2
#                                         AG-409-B05      60001830       6
#                                                         60002365       4
#                                         AG-409-B13      60001830       4
#                                         AG-409-C21      60001830       5
#                                                         60001888       1
#                                         AG-409-D20      60001888       1
#                                         AG-409-E05      60001830       2
#                                         AG-409-G20      60001830       3
#                                         AG-409-I21      60001830       2
#                                         AG-409-J16      60001830       2
#                                         AG-409-J19      60001830       2
#                                         AG-409-L14      60001830       3
#                                         AG-409-L18      60001830       2
#                                         AG-409-N21      60001830       4
#                                         AG-409-O23      60001830       4
#                                         AG-409-P19      60001830       1
#                                                         60001883       1
#                                         AG-463-N15      60001830       4
#                                         AG-463-P14      60001830       1
#                                         W5              60001830       1
#                                         W9              60001830       3
#                                         scB243_498P3    60001888       2
#                                                         60002365       1
#                                         scB245a_518K17  60001883       2
#                                                         60001888       1
#                                         scB245a_520B18  60001830       1
#                                                         60001888       1
#                                         scB245a_520K10  60002365       3
#                                         scB245a_521K15  60002365       1
#                                         scB245a_521M10  60001888       3
# Synechococcus    5.1-UC-A      ISOLATE  KORDI-100       60001830      14
#                                                         60001888       2
#                                                         60002365       1
#                  5.1A-I        SAG      AG-683-A02      60001830       1
#                                         AG-686-A03      60001830       3
#                                         AG-686-F08      60002365       1
#                  5.1A-II       ISOLATE  WH8109          60002365       3
#                                                         60001830       1
#                                SAG      AG-670-A04      60001830       1
#                                                         60001888       1
#                                         AG-670-A19      60001830       2
#                                         AG-670-B23      60001830       1
#                                                         60002365       1
#                                         AG-670-G20      60001830       2
#                                                         60002365       1
#                  5.1A-III      ISOLATE  WH8102          60001830       5
#                                                         60001883       2
#                                                         60001888       1
#                                SAG      AG-670-A05      60001830       3
#                                                         60001888       1
#                  5.1A-III/XV   SAG      AG-670-D07      60001830       5
#                                                         60001888       2
#                                         AG-670-F04      60001830      21
#                                                         60001888       5
#                                                         60002365       1
#                  5.1A-IV       ISOLATE  BL107           60001888       1
#                                         CC9902          60001830       2
#                                SAG      AG-683-A22      60001830       2
#                                         AG-683-B03      60001830       2
#                                                         60002365       1
#                                         AG-683-B21      60001830       3
#                                         AG-683-C23      60001830       6
#                                                         60001883       1
#                                         AG-686-B21      60001830       5
#                                                         60001883       1
#                                         AG-686-C21      60001830       4
#                                         AG-686-C23      60001830       1
#                  5.1A-WPC1     ISOLATE  KORDI-49        60001830       2
#                                                         60001883       1
#                                                         60002365       1
#                  5.1B-IX       ISOLATE  RS9916          60002365       3
#                                                         60001830       2
#                  5.1B-V        ISOLATE  WH7803          60001830       2
#                  5.1B-VI       ISOLATE  WH7805          60001830       4
#                                                         60002365       1
#                  5.1B-VII      ISOLATE  MIT9504         60002365       4
#                                                         60001830       2
#                                         MIT9508         60002365       2
#                                         MIT9509         60002365       3
#                                                         60001830       2
#                                SAG      AG-323-A01      60001830       1
#                                                         60002365       1
#                                         AG-670-F22      60001883       1
#                                                         60001888       1
#                                         AG-673-A03      60001883       1
#                                         AG-673-D02      60002365       1
#                                         AG-673-F03      60001888       2
#                                                         60001830       1
#                                         AG-676-A21      60002365       2
#                                                         60001888       1
#                                         AG-676-C06      60001830       1
#                                         AG-679-A02      60001883       1
#                                         AG-679-E23      60001830       5
#                                         AG-683-G11      60001883       1
#                                         AG-686-D09      60001830       2
#                  5.3-I / X     ISOLATE  RCC307          60001830       6
#                  CRD2          SAG      AG-673-A10      60001830       4
#                                                         60001888       2
#                                         AG-673-B04      60001830       5
#                                         AG-673-B08      60001830       4
#                                                         60001883       1
#                                                         60001888       1
#                                         AG-676-A03      60001830       1
#                                         AG-676-F02      60001830       6
#                                                         60001883       1
#                                                         60001888       1
#                                         AG-679-B05      60001830       3
#                                                         60001888       1
#                                         AG-679-B21      60001830       3
#                                                         60001888       2
#                                         AG-679-D13      60001830       7
#                                                         60001888       3
#                  Not Assigned  ISOLATE  CC9616          60001830       6
#                                                         60001888       2
#                                         WH8020          60002365       1
#                                         WH8103          60001830       3
#                                                         60001883       1
#                                                         60001888       1
#                                SAG      AG-323-O22      60001830       3
#                                                         60001888       2
#                                                         60002365       1
#                                         AG-420-M02      60001830       4
#                                                         60002365       1
#                                         AG-450-M17      60002365       1
#                                         AG-676-E04      60001830       3
#                                                         60001888       1
# Virus            Not Assigned  ISOLATE  P-SSM2          60001888       1
#                                         P-SSM5          60001888       1
#                                SAG      AG-345-E02      60001888       1
#                                         AG-345-F15      60001888       1
#                                         AG-345-P14      60001888       1
# Name: OrthologID, dtype: int64
